# %% [markdown]
# # Class3 számrendszerek

# %% [markdown]
# ## Számrendszerek

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo("xSi0lfl-31U")
# ez a legfontosabb, 10 perc:

# %%
YouTubeVideo("15sLPp0YvQk")
# római számok, meglepően jól előadva, 5 perc

# %%
YouTubeVideo("5sS7w-CMHkU")
# ez a konkrét 16-os, de az első nélkül sztem túl technikai, 14 perc)

# %% [markdown]
# ### Fun facts

# %% [markdown]
# A 10-es számrendszer az emberi anatómiából jön, csakúgy, mint a 12-es!
#
# dozen = 12 = tucat
#
# gross = 144 (= 12 * 12) = nagytucat
#
# 12-es számrendszer:
# https://hu.wikipedia.org/wiki/Tucat

# %%
YouTubeVideo('U6xJfP7-HCc')
# előnyei, ha a 12-est használnánk, 9 perc

# %%
YouTubeVideo('QZVkWY9G2JQ')
# egy kézen 12-ig számolás, 12 másodperc

# %% [markdown]
# A 11 (eleven) és a 12 (twelve) a germán nyelvekben nem reguláris (http://www.etymonline.com/index.php?allowed_in_frame=0&search=Eleven&searchmode=none), kötődik mind a 10-eshez, mind a 12-eshez.
